# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import keras

# %%
DATA_PATH = "data.json"  
actual= []
predicted=[]

# %%
def load_data(data_path):
    """Loads training dataset from json file.

        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y

# %%
def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs

        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2, figsize=(10, 10))

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="Train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="Test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].set_xlabel("Epoch")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="Train error")
    axs[1].plot(history.history["val_loss"], label="Test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    fig.tight_layout(pad=1.5)
    axs[0].grid()
    axs[1].grid()

    plt.show()

# %%
def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.

    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split

    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test

# %%
def build_model(input_shape):
    """Generates CNN model

    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(32, (2, 2), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed it into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    # output layer
    model.add(keras.layers.Dense(10, activation='softmax'))

    return model

# %%
def predict(model, X, y):
    """Predict a single sample using the trained model

    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)
    actual.append(y)
    predicted.append(predicted_index)
    print("Target: {}, Predicted label: {}".format(y, predicted_index))

# %%
if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=30)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # pick a sample to predict from the test set
    X_to_predict = X_test[100]
    y_to_predict = y_test[100]

    # predict sample
    predict(model, X_to_predict, y_to_predict)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 128, 11, 32)       320
#
#  max_pooling2d_6 (MaxPooling  (None, 64, 6, 32)        0
#  2D)
#
#  batch_normalization_6 (Batc  (None, 64, 6, 32)        128
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 62, 4, 32)         9248
#
#  max_pooling2d_7 (MaxPooling  (None, 31, 2, 32)        0
#  2D)
#
#  batch_normalization_7 (Batc  (None, 31, 2, 32)        128
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 30, 1, 32)         4128
#
#  max_pooling2d_8 (MaxPooling  (None, 15, 1, 32)        0
#  2D)
#
#  batch_normalization_8 (Batc  (None, 15, 1, 32)        128
#  hNormalization)
#
#  flatten_4 (Flatten)         (None, 480)               0
#
#  dense_12 (Dense)            (None, 64)                30784
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_13 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 45,514
# Trainable params: 45,322
# Non-trainable params: 192
# _________________________________________________________________
# Epoch 1/30
# 188/188 [==============================] - 6s 27ms/step - loss: 2.4223 - accuracy: 0.2258 - val_loss: 1.8683 - val_accuracy: 0.3311
# Epoch 2/30
# 188/188 [==============================] - 5s 26ms/step - loss: 1.8798 - accuracy: 0.3554 - val_loss: 1.5350 - val_accuracy: 0.4346
# Epoch 3/30
# 188/188 [==============================] - 5s 24ms/step - loss: 1.6578 - accuracy: 0.4171 - val_loss: 1.4037 - val_accuracy: 0.4786
# Epoch 4/30
# 188/188 [==============================] - 5s 24ms/step - loss: 1.5234 - accuracy: 0.4567 - val_loss: 1.3225 - val_accuracy: 0.5234
# Epoch 5/30
# 188/188 [==============================] - 4s 24ms/step - loss: 1.4174 - accuracy: 0.4937 - val_loss: 1.2462 - val_accuracy: 0.5507
# Epoch 6/30
# 188/188 [==============================] - 5s 25ms/step - loss: 1.3527 - accuracy: 0.5225 - val_loss: 1.1909 - val_accuracy: 0.5708
# Epoch 7/30
# 188/188 [==============================] - 5s 24ms/step - loss: 1.2869 - accuracy: 0.5428 - val_loss: 1.1605 - val_accuracy: 0.5748
# Epoch 8/30
# 188/188 [==============================] - 5s 24ms/step - loss: 1.2462 - accuracy: 0.5533 - val_loss: 1.1273 - val_accuracy: 0.6015
# Epoch 9/30
# 188/188 [==============================] - 5s 25ms/step - loss: 1.1926 - accuracy: 0.5835 - val_loss: 1.1152 - val_accuracy: 0.5928
# Epoch 10/30
# 188/188 [==============================] - 5s 24ms/step - loss: 1.1513 - accuracy: 0.5901 - val_loss: 1.0869 - val_accuracy: 0.5981
# Epoch 11/30
# 188/188 [==============================] - 5s 24ms/step - loss: 1.1105 - accuracy: 0.6111 - val_loss: 1.0596 - val_accuracy: 0.6168
# Epoch 12/30
# 188/188 [==============================] - 4s 24ms/step - loss: 1.0712 - accuracy: 0.6251 - val_loss: 1.0476 - val_accuracy: 0.6262
# Epoch 13/30
# 188/188 [==============================] - 4s 24ms/step - loss: 1.0452 - accuracy: 0.6304 - val_loss: 1.0461 - val_accuracy: 0.6255
# Epoch 14/30
# 188/188 [==============================] - 5s 25ms/step - loss: 1.0093 - accuracy: 0.6426 - val_loss: 0.9984 - val_accuracy: 0.6429
# Epoch 15/30
# 188/188 [==============================] - 5s 24ms/step - loss: 0.9873 - accuracy: 0.6533 - val_loss: 0.9968 - val_accuracy: 0.6422
# Epoch 16/30
# 188/188 [==============================] - 4s 24ms/step - loss: 0.9715 - accuracy: 0.6572 - val_loss: 0.9709 - val_accuracy: 0.6495
# Epoch 17/30
# 188/188 [==============================] - 5s 24ms/step - loss: 0.9308 - accuracy: 0.6750 - val_loss: 0.9490 - val_accuracy: 0.6682
# Epoch 18/30
# 188/188 [==============================] - 5s 25ms/step - loss: 0.9148 - accuracy: 0.6752 - val_loss: 0.9534 - val_accuracy: 0.6602
# Epoch 19/30
# 188/188 [==============================] - 4s 24ms/step - loss: 0.8827 - accuracy: 0.6925 - val_loss: 0.9270 - val_accuracy: 0.6736
# Epoch 20/30
# 188/188 [==============================] - 4s 23ms/step - loss: 0.8752 - accuracy: 0.6917 - val_loss: 0.9026 - val_accuracy: 0.6789
# Epoch 21/30
# 188/188 [==============================] - 5s 25ms/step - loss: 0.8496 - accuracy: 0.7017 - val_loss: 0.9233 - val_accuracy: 0.6676
# Epoch 22/30
# 188/188 [==============================] - 4s 24ms/step - loss: 0.8435 - accuracy: 0.7082 - val_loss: 0.8918 - val_accuracy: 0.6816
# Epoch 23/30
# 188/188 [==============================] - 5s 25ms/step - loss: 0.8176 - accuracy: 0.7089 - val_loss: 0.8960 - val_accuracy: 0.6876
# Epoch 24/30
# 188/188 [==============================] - 6s 29ms/step - loss: 0.7798 - accuracy: 0.7224 - val_loss: 0.8738 - val_accuracy: 0.6836
# Epoch 25/30
# 188/188 [==============================] - 5s 27ms/step - loss: 0.7801 - accuracy: 0.7309 - val_loss: 0.8728 - val_accuracy: 0.6923
# Epoch 26/30
# 188/188 [==============================] - 5s 26ms/step - loss: 0.7630 - accuracy: 0.7351 - val_loss: 0.8695 - val_accuracy: 0.6936
# Epoch 27/30
# 188/188 [==============================] - 5s 25ms/step - loss: 0.7479 - accuracy: 0.7436 - val_loss: 0.8555 - val_accuracy: 0.7036
# Epoch 28/30
# 188/188 [==============================] - 5s 25ms/step - loss: 0.7145 - accuracy: 0.7520 - val_loss: 0.8578 - val_accuracy: 0.7043
# Epoch 29/30
# 188/188 [==============================] - 5s 26ms/step - loss: 0.7109 - accuracy: 0.7541 - val_loss: 0.8296 - val_accuracy: 0.7109
# Epoch 30/30
# 188/188 [==============================] - 5s 25ms/step - loss: 0.6967 - accuracy: 0.7578 - val_loss: 0.8617 - val_accuracy: 0.7089
# 79/79 - 1s - loss: 0.8351 - accuracy: 0.7157 - 872ms/epoch - 11ms/step
#
# Test accuracy: 0.7156587839126587
# 1/1 [==============================] - 0s 263ms/step
# Target: 5, Predicted label: [5]

# %%
count= X_test.shape[0]
count
# Out:
# 2497

# %%
for i in range(count):
    X_to_predict = X_test[i]
    y_to_predict = y_test[i]
    predict(model, X_to_predict, y_to_predict)
# Out:
# 1/1 [==============================] - 0s 42ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 45ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 43ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 45ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 41ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 41ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 41ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 42ms/step
# Target: 5, Predicted label: [2]
# 1/1 [==============================] - 0s 43ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 44ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 45ms/step
# Target: 8, Predicted label: [7]
# 1/1 [==============================] - 0s 44ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 46ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 46ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 48ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 41ms/step
# Target: 5, Predicted label: [8]
# 1/1 [==============================] - 0s 42ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 42ms/step
# Target: 8, Predicted label: [7]
# 1/1 [==============================] - 0s 44ms/step
# Target: 9, Predicted label: [2]
# 1/1 [==============================] - 0s 49ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 44ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 40ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 39ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 42ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 44ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 43ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 47ms/step
# Target: 2, Predicted label: [9]
# 1/1 [==============================] - 0s 43ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 41ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 41ms/step
# Target: 4, Predicted label: [3]
# 1/1 [==============================] - 0s 42ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 44ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 39ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 41ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 42ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 43ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 43ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 43ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [9]
# 1/1 [==============================] - 0s 44ms/step
# Target: 9, Predicted label: [3]
# 1/1 [==============================] - 0s 44ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 51ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 47ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 44ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 46ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 45ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 46ms/step
# Target: 3, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 8, Predicted label: [4]
# 1/1 [==============================] - 0s 47ms/step
# Target: 0, Predicted label: [2]
# 1/1 [==============================] - 0s 48ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 47ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [1]
# 1/1 [==============================] - 0s 47ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 46ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 47ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 49ms/step
# Target: 4, Predicted label: [0]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 44ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 48ms/step
# Target: 4, Predicted label: [2]
# 1/1 [==============================] - 0s 47ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 47ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 46ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 44ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 60ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 46ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 48ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 43ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 45ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 47ms/step
# Target: 0, Predicted label: [6]
# 1/1 [==============================] - 0s 46ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 45ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 47ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 44ms/step
# Target: 0, Predicted label: [6]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [0]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 46ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 48ms/step
# Target: 9, Predicted label: [5]
# 1/1 [==============================] - 0s 47ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 47ms/step
# Target: 2, Predicted label: [1]
# 1/1 [==============================] - 0s 47ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 45ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 47ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 45ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 45ms/step
# Target: 9, Predicted label: [3]
# 1/1 [==============================] - 0s 47ms/step
# Target: 9, Predicted label: [5]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 71ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 45ms/step
# Target: 4, Predicted label: [8]
# 1/1 [==============================] - 0s 44ms/step
# Target: 4, Predicted label: [0]
# 1/1 [==============================] - 0s 47ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 46ms/step
# Target: 3, Predicted label: [7]
# 1/1 [==============================] - 0s 47ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 45ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 47ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 48ms/step
# Target: 0, Predicted label: [5]
# 1/1 [==============================] - 0s 51ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 47ms/step
# Target: 0, Predicted label: [2]
# 1/1 [==============================] - 0s 48ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 47ms/step
# Target: 2, Predicted label: [5]
# 1/1 [==============================] - 0s 47ms/step
# Target: 3, Predicted label: [9]
# 1/1 [==============================] - 0s 51ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 48ms/step
# Target: 9, Predicted label: [6]
# 1/1 [==============================] - 0s 46ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 46ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 160ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 46ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 47ms/step
# Target: 8, Predicted label: [2]
# 1/1 [==============================] - 0s 46ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 151ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 44ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 48ms/step
# Target: 8, Predicted label: [2]
# 1/1 [==============================] - 0s 46ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 47ms/step
# Target: 4, Predicted label: [6]
# 1/1 [==============================] - 0s 46ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 46ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 46ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 47ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 45ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 45ms/step
# Target: 8, Predicted label: [4]
# 1/1 [==============================] - 0s 48ms/step
# Target: 7, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 4, Predicted label: [6]
# 1/1 [==============================] - 0s 47ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 48ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 48ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 45ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 47ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 47ms/step
# Target: 8, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 47ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 48ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 47ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 47ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 47ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 49ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 47ms/step
# Target: 7, Predicted label: [3]
# 1/1 [==============================] - 0s 48ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 47ms/step
# Target: 4, Predicted label: [3]
# 1/1 [==============================] - 0s 49ms/step
# Target: 5, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 47ms/step
# Target: 7, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 48ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 48ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 46ms/step
# Target: 0, Predicted label: [6]
# 1/1 [==============================] - 0s 46ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 44ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 47ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 46ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 47ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 45ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 48ms/step
# Target: 8, Predicted label: [4]
# 1/1 [==============================] - 0s 48ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 48ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 48ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 49ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 48ms/step
# Target: 2, Predicted label: [7]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 46ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 48ms/step
# Target: 3, Predicted label: [7]
# 1/1 [==============================] - 0s 47ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 49ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 48ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 45ms/step
# Target: 8, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 47ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 47ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 48ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 45ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 46ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 47ms/step
# Target: 0, Predicted label: [2]
# 1/1 [==============================] - 0s 47ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 48ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 46ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 46ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 48ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 48ms/step
# Target: 8, Predicted label: [3]
# 1/1 [==============================] - 0s 77ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 49ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 46ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 45ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 46ms/step
# Target: 8, Predicted label: [9]
# 1/1 [==============================] - 0s 45ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 48ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 46ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 45ms/step
# Target: 2, Predicted label: [0]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 46ms/step
# Target: 4, Predicted label: [7]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 46ms/step
# Target: 8, Predicted label: [2]
# 1/1 [==============================] - 0s 48ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 46ms/step
# Target: 3, Predicted label: [5]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 45ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 47ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 47ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 48ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 46ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 360ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 47ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 47ms/step
# Target: 9, Predicted label: [6]
# 1/1 [==============================] - 0s 46ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 48ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 48ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 46ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 48ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 47ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 46ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 49ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 0, Predicted label: [6]
# 1/1 [==============================] - 0s 45ms/step
# Target: 2, Predicted label: [0]
# 1/1 [==============================] - 0s 47ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 46ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 46ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 51ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 47ms/step
# Target: 9, Predicted label: [2]
# 1/1 [==============================] - 0s 47ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 84ms/step
# Target: 4, Predicted label: [3]
# 1/1 [==============================] - 0s 45ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 47ms/step
# Target: 3, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [3]
# 1/1 [==============================] - 0s 45ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 71ms/step
# Target: 7, Predicted label: [4]
# 1/1 [==============================] - 0s 44ms/step
# Target: 6, Predicted label: [4]
# 1/1 [==============================] - 0s 48ms/step
# Target: 8, Predicted label: [3]
# 1/1 [==============================] - 0s 46ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 46ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 47ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 46ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 48ms/step
# Target: 7, Predicted label: [1]
# 1/1 [==============================] - 0s 47ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 48ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 46ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 48ms/step
# Target: 4, Predicted label: [6]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 4, Predicted label: [7]
# 1/1 [==============================] - 0s 297ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 44ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 45ms/step
# Target: 4, Predicted label: [2]
# 1/1 [==============================] - 0s 47ms/step
# Target: 0, Predicted label: [1]
# 1/1 [==============================] - 0s 41ms/step
# Target: 2, Predicted label: [3]
# 1/1 [==============================] - 0s 48ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 48ms/step
# Target: 0, Predicted label: [2]
# 1/1 [==============================] - 0s 44ms/step
# Target: 6, Predicted label: [3]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [1]
# 1/1 [==============================] - 0s 46ms/step
# Target: 4, Predicted label: [3]
# 1/1 [==============================] - 0s 49ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 0, Predicted label: [9]
# 1/1 [==============================] - 0s 40ms/step
# Target: 8, Predicted label: [4]
# 1/1 [==============================] - 0s 47ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 46ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 45ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 46ms/step
# Target: 5, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 82ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 46ms/step
# Target: 4, Predicted label: [2]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [1]
# 1/1 [==============================] - 0s 59ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 46ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 46ms/step
# Target: 4, Predicted label: [7]
# 1/1 [==============================] - 0s 47ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 45ms/step
# Target: 4, Predicted label: [6]
# 1/1 [==============================] - 0s 46ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 46ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 46ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 47ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 47ms/step
# Target: 9, Predicted label: [3]
# 1/1 [==============================] - 0s 46ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 47ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 46ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 48ms/step
# Target: 7, Predicted label: [2]
# 1/1 [==============================] - 0s 48ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 45ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 49ms/step
# Target: 0, Predicted label: [6]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 45ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 45ms/step
# Target: 6, Predicted label: [5]
# 1/1 [==============================] - 0s 47ms/step
# Target: 0, Predicted label: [9]
# 1/1 [==============================] - 0s 45ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 47ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 48ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 45ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 47ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 46ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 48ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 47ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 47ms/step
# Target: 2, Predicted label: [9]
# 1/1 [==============================] - 0s 49ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 47ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 49ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 45ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 47ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 45ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 48ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 45ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 44ms/step
# Target: 8, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 45ms/step
# Target: 3, Predicted label: [7]
# 1/1 [==============================] - 0s 46ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 44ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 46ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 45ms/step
# Target: 4, Predicted label: [3]
# 1/1 [==============================] - 0s 50ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [7]
# 1/1 [==============================] - 0s 46ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 8, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 4, Predicted label: [8]
# 1/1 [==============================] - 0s 46ms/step
# Target: 6, Predicted label: [5]
# 1/1 [==============================] - 0s 46ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 45ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 46ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 45ms/step
# Target: 0, Predicted label: [6]
# 1/1 [==============================] - 0s 46ms/step
# Target: 2, Predicted label: [5]
# 1/1 [==============================] - 0s 118ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 46ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 45ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 45ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 44ms/step
# Target: 5, Predicted label: [1]
# 1/1 [==============================] - 0s 48ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 47ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 46ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 44ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 47ms/step
# Target: 0, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 47ms/step
# Target: 2, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 6, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 45ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 46ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 46ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 45ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 47ms/step
# Target: 3, Predicted label: [7]
# 1/1 [==============================] - 0s 45ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 47ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 45ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 203ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 45ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 46ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 44ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 46ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 45ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 47ms/step
# Target: 8, Predicted label: [2]
# 1/1 [==============================] - 0s 46ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 46ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 45ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 44ms/step
# Target: 4, Predicted label: [2]
# 1/1 [==============================] - 0s 93ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 47ms/step
# Target: 4, Predicted label: [3]
# 1/1 [==============================] - 0s 47ms/step
# Target: 9, Predicted label: [8]
# 1/1 [==============================] - 0s 46ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 48ms/step
# Target: 6, Predicted label: [4]
# 1/1 [==============================] - 0s 44ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 46ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 48ms/step
# Target: 5, Predicted label: [0]
# 1/1 [==============================] - 0s 48ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 45ms/step
# Target: 2, Predicted label: [0]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [3]
# 1/1 [==============================] - 0s 45ms/step
# Target: 8, Predicted label: [4]
# 1/1 [==============================] - 0s 45ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 48ms/step
# Target: 3, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 47ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 47ms/step
# Target: 9, Predicted label: [8]
# 1/1 [==============================] - 0s 43ms/step
# Target: 8, Predicted label: [0]
# 1/1 [==============================] - 0s 46ms/step
# Target: 2, Predicted label: [0]
# 1/1 [==============================] - 0s 46ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 46ms/step
# Target: 3, Predicted label: [0]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [1]
# 1/1 [==============================] - 0s 45ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 134ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 44ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 46ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 44ms/step
# Target: 0, Predicted label: [6]
# 1/1 [==============================] - 0s 45ms/step
# Target: 5, Predicted label: [0]
# 1/1 [==============================] - 0s 48ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 46ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 46ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 47ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 47ms/step
# Target: 2, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 46ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 46ms/step
# Target: 4, Predicted label: [3]
# 1/1 [==============================] - 0s 51ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 45ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 45ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 47ms/step
# Target: 2, Predicted label: [1]
# 1/1 [==============================] - 0s 46ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 46ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 46ms/step
# Target: 4, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [0]
# 1/1 [==============================] - 0s 46ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 46ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 45ms/step
# Target: 0, Predicted label: [6]
# 1/1 [==============================] - 0s 47ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 45ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 45ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 47ms/step
# Target: 0, Predicted label: [5]
# 1/1 [==============================] - 0s 46ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 47ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 46ms/step
# Target: 3, Predicted label: [4]
# 1/1 [==============================] - 0s 50ms/step
# Target: 3, Predicted label: [7]
# 1/1 [==============================] - 0s 48ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 47ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 46ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 46ms/step
# Target: 4, Predicted label: [6]
# 1/1 [==============================] - 0s 48ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 48ms/step
# Target: 2, Predicted label: [5]
# 1/1 [==============================] - 0s 45ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 46ms/step
# Target: 5, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 46ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 47ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 46ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 44ms/step
# Target: 4, Predicted label: [7]
# 1/1 [==============================] - 0s 44ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 235ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [7]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 224ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 47ms/step
# Target: 8, Predicted label: [2]
# 1/1 [==============================] - 0s 47ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 46ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 48ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 47ms/step
# Target: 2, Predicted label: [0]
# 1/1 [==============================] - 0s 48ms/step
# Target: 7, Predicted label: [9]
# 1/1 [==============================] - 0s 45ms/step
# Target: 4, Predicted label: [7]
# 1/1 [==============================] - 0s 45ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 44ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 41ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 45ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 47ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 51ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 47ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 43ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 49ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 46ms/step
# Target: 3, Predicted label: [8]
# 1/1 [==============================] - 0s 48ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 55ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 45ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 41ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 45ms/step
# Target: 2, Predicted label: [9]
# 1/1 [==============================] - 0s 48ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 38ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 40ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 43ms/step
# Target: 3, Predicted label: [9]
# 1/1 [==============================] - 0s 136ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 43ms/step
# Target: 0, Predicted label: [2]
# 1/1 [==============================] - 0s 42ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 46ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 43ms/step
# Target: 3, Predicted label: [7]
# 1/1 [==============================] - 0s 44ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 40ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 39ms/step
# Target: 0, Predicted label: [1]
# 1/1 [==============================] - 0s 41ms/step
# Target: 2, Predicted label: [5]
# 1/1 [==============================] - 0s 117ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 347ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 44ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 45ms/step
# Target: 8, Predicted label: [9]
# 1/1 [==============================] - 0s 44ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 49ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 40ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 42ms/step
# Target: 4, Predicted label: [6]
# 1/1 [==============================] - 0s 39ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 40ms/step
# Target: 8, Predicted label: [9]
# 1/1 [==============================] - 0s 39ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 43ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 41ms/step
# Target: 2, Predicted label: [9]
# 1/1 [==============================] - 0s 42ms/step
# Target: 8, Predicted label: [9]
# 1/1 [==============================] - 0s 41ms/step
# Target: 9, Predicted label: [2]
# 1/1 [==============================] - 0s 38ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 44ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 40ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 41ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 38ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 40ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 61ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 38ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 39ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 41ms/step
# Target: 7, Predicted label: [5]
# 1/1 [==============================] - 0s 41ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 45ms/step
# Target: 4, Predicted label: [0]
# 1/1 [==============================] - 0s 46ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 44ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 44ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 51ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 345ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 45ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 44ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 46ms/step
# Target: 4, Predicted label: [8]
# 1/1 [==============================] - 0s 43ms/step
# Target: 2, Predicted label: [1]
# 1/1 [==============================] - 0s 42ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 49ms/step
# Target: 5, Predicted label: [2]
# 1/1 [==============================] - 0s 275ms/step
# Target: 8, Predicted label: [4]
# 1/1 [==============================] - 0s 60ms/step
# Target: 5, Predicted label: [2]
# 1/1 [==============================] - 0s 47ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 43ms/step
# Target: 3, Predicted label: [9]
# 1/1 [==============================] - 0s 41ms/step
# Target: 1, Predicted label: [5]
# 1/1 [==============================] - 0s 45ms/step
# Target: 9, Predicted label: [2]
# 1/1 [==============================] - 0s 44ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 42ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 43ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 43ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 45ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 45ms/step
# Target: 4, Predicted label: [8]
# 1/1 [==============================] - 0s 45ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 254ms/step
# Target: 4, Predicted label: [0]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 42ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 46ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 46ms/step
# Target: 0, Predicted label: [1]
# 1/1 [==============================] - 0s 44ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 43ms/step
# Target: 2, Predicted label: [1]
# 1/1 [==============================] - 0s 46ms/step
# Target: 4, Predicted label: [6]
# 1/1 [==============================] - 0s 41ms/step
# Target: 0, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [9]
# ...
# Target: 2, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 8, Predicted label: [2]
# 1/1 [==============================] - 0s 55ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 45ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 49ms/step
# Target: 4, Predicted label: [3]
# 1/1 [==============================] - 0s 48ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 74ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 45ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 44ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 47ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 47ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 47ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 45ms/step
# Target: 3, Predicted label: [0]
# 1/1 [==============================] - 0s 47ms/step
# Target: 4, Predicted label: [7]
# 1/1 [==============================] - 0s 46ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 48ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 56ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 45ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 46ms/step
# Target: 3, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 9, Predicted label: [3]
# 1/1 [==============================] - 0s 47ms/step
# Target: 4, Predicted label: [8]
# 1/1 [==============================] - 0s 47ms/step
# Target: 2, Predicted label: [9]
# 1/1 [==============================] - 0s 49ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 46ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 43ms/step
# Target: 7, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 70ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 46ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [5]
# 1/1 [==============================] - 0s 47ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 47ms/step
# Target: 9, Predicted label: [0]
# 1/1 [==============================] - 0s 47ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 44ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 46ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 44ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 67ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 45ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 45ms/step
# Target: 4, Predicted label: [7]
# 1/1 [==============================] - 0s 48ms/step
# Target: 3, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [6]
# 1/1 [==============================] - 0s 47ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 48ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 48ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 46ms/step
# Target: 3, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 52ms/step
# Target: 1, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 46ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 47ms/step
# Target: 6, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 4, Predicted label: [3]
# 1/1 [==============================] - 0s 45ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 45ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 45ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 75ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 45ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 46ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 46ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 48ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 46ms/step
# Target: 0, Predicted label: [2]
# 1/1 [==============================] - 0s 48ms/step
# Target: 2, Predicted label: [0]
# 1/1 [==============================] - 0s 46ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 46ms/step
# Target: 4, Predicted label: [7]
# 1/1 [==============================] - 0s 47ms/step
# Target: 4, Predicted label: [8]
# 1/1 [==============================] - 0s 46ms/step
# Target: 3, Predicted label: [7]
# 1/1 [==============================] - 0s 56ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 45ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 47ms/step
# Target: 7, Predicted label: [3]
# 1/1 [==============================] - 0s 47ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 44ms/step
# Target: 9, Predicted label: [3]
# 1/1 [==============================] - 0s 46ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 58ms/step
# Target: 5, Predicted label: [1]
# 1/1 [==============================] - 0s 43ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 48ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 72ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 45ms/step
# Target: 6, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 44ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 46ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 47ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 44ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 46ms/step
# Target: 0, Predicted label: [2]
# 1/1 [==============================] - 0s 45ms/step
# Target: 7, Predicted label: [9]
# 1/1 [==============================] - 0s 47ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 45ms/step
# Target: 3, Predicted label: [2]
# 1/1 [==============================] - 0s 46ms/step
# Target: 4, Predicted label: [6]
# 1/1 [==============================] - 0s 66ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 48ms/step
# Target: 5, Predicted label: [1]
# 1/1 [==============================] - 0s 46ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 45ms/step
# Target: 0, Predicted label: [2]
# 1/1 [==============================] - 0s 45ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 45ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 46ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 46ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 45ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 26ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 46ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 45ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 45ms/step
# Target: 3, Predicted label: [0]
# 1/1 [==============================] - 0s 45ms/step
# Target: 5, Predicted label: [8]
# 1/1 [==============================] - 0s 43ms/step
# Target: 9, Predicted label: [3]
# 1/1 [==============================] - 0s 52ms/step
# Target: 0, Predicted label: [9]
# 1/1 [==============================] - 0s 45ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 45ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 45ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 63ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 44ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 45ms/step
# Target: 8, Predicted label: [3]
# 1/1 [==============================] - 0s 45ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 52ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 44ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 47ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 43ms/step
# Target: 6, Predicted label: [9]
# 1/1 [==============================] - 0s 66ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 45ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 47ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 47ms/step
# Target: 9, Predicted label: [6]
# 1/1 [==============================] - 0s 45ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 44ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 44ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 53ms/step
# Target: 4, Predicted label: [3]
# 1/1 [==============================] - 0s 76ms/step
# Target: 3, Predicted label: [6]
# 1/1 [==============================] - 0s 43ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 44ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 54ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 44ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 44ms/step
# Target: 7, Predicted label: [3]
# 1/1 [==============================] - 0s 44ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 58ms/step
# Target: 0, Predicted label: [2]
# 1/1 [==============================] - 0s 45ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [3]
# 1/1 [==============================] - 0s 49ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 44ms/step
# Target: 2, Predicted label: [1]
# 1/1 [==============================] - 0s 47ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 44ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 46ms/step
# Target: 9, Predicted label: [6]
# 1/1 [==============================] - 0s 45ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 46ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 45ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 46ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 47ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 59ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 45ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 46ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 44ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 44ms/step
# Target: 3, Predicted label: [2]
# 1/1 [==============================] - 0s 44ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 46ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 60ms/step
# Target: 9, Predicted label: [0]
# 1/1 [==============================] - 0s 45ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 44ms/step
# Target: 3, Predicted label: [9]
# 1/1 [==============================] - 0s 68ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 44ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 43ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 44ms/step
# Target: 2, Predicted label: [2]
# 1/1 [==============================] - 0s 46ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 52ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 46ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 46ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 45ms/step
# Target: 1, Predicted label: [1]
# 1/1 [==============================] - 0s 46ms/step
# Target: 8, Predicted label: [0]
# 1/1 [==============================] - 0s 58ms/step
# Target: 2, Predicted label: [8]
# 1/1 [==============================] - 0s 45ms/step
# Target: 8, Predicted label: [4]
# 1/1 [==============================] - 0s 44ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 43ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 45ms/step
# Target: 9, Predicted label: [6]
# 1/1 [==============================] - 0s 46ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 42ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 55ms/step
# Target: 5, Predicted label: [5]
# 1/1 [==============================] - 0s 44ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 81ms/step
# Target: 4, Predicted label: [3]
# 1/1 [==============================] - 0s 45ms/step
# Target: 4, Predicted label: [8]
# 1/1 [==============================] - 0s 42ms/step
# Target: 6, Predicted label: [9]
# 1/1 [==============================] - 0s 46ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 45ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 46ms/step
# Target: 6, Predicted label: [6]
# 1/1 [==============================] - 0s 45ms/step
# Target: 3, Predicted label: [3]
# 1/1 [==============================] - 0s 46ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 115ms/step
# Target: 7, Predicted label: [7]
# 1/1 [==============================] - 0s 43ms/step
# Target: 4, Predicted label: [4]
# 1/1 [==============================] - 0s 45ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 48ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 45ms/step
# Target: 0, Predicted label: [5]
# 1/1 [==============================] - 0s 46ms/step
# Target: 0, Predicted label: [0]
# 1/1 [==============================] - 0s 46ms/step
# Target: 3, Predicted label: [6]
# 1/1 [==============================] - 0s 45ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 45ms/step
# Target: 8, Predicted label: [8]
# 1/1 [==============================] - 0s 129ms/step
# Target: 9, Predicted label: [9]
# 1/1 [==============================] - 0s 44ms/step
# Target: 2, Predicted label: [3]

# %%
def Extract(predicted):
    return [item[0] for item in predicted]
predicted2= Extract(predicted)

# %%
import pandas as pd

# Create a dataframe from the lists
df = pd.DataFrame({'actual': actual, 'predicted': predicted2})

df.to_json('actual_prediction.json', orient='records')
